# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import os

# %%
address = "C:/Users/Harahitha Divakar/Desktop/SEM7/DS/assignment/ionosphere_data.csv"
data = pd.read_csv(address)

# %%
data.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# ...

# %%
print(data.shape)
# Out:
# (351, 35)

# %%
print(data['feature2'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 346    0
# 347    0
# 348    0
# 349    0
# 350    0
# Name: feature2, Length: 351, dtype: int64

# %%
print(data['feature2'].var())
# Out:
# 0.0

# %%
data.drop('feature2',axis=1)
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 0           1   0.99539  -0.05889   0.85243   0.02306   0.83398  -0.37708
# 1           1   1.00000  -0.18829   0.93035  -0.36156  -0.10868  -0.93597
# 2           1   1.00000  -0.03365   1.00000   0.00485   1.00000  -0.12062
# 3           1   1.00000  -0.45161   1.00000   1.00000   0.71216  -1.00000
# 4           1   1.00000  -0.02401   0.94140   0.06531   0.92106  -0.23255
# ..        ...       ...       ...       ...       ...       ...       ...
# 346         1   0.83508   0.08298   0.73739  -0.14706   0.84349  -0.05567
# 347         1   0.95113   0.00419   0.95183  -0.02723   0.93438  -0.01920
# 348         1   0.94701  -0.00034   0.93207  -0.03227   0.95177  -0.03431
# 349         1   0.90608  -0.01657   0.98122  -0.01989   0.95691  -0.03646
# 350         1   0.84710   0.13533   0.73638  -0.06151   0.87873   0.08260
#
#      feature9  feature10  feature11  ...  feature26  feature27  feature28  \
# ...

# %%
data.shape
# Out:
# (351, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
data.label.value_counts()
# Out:
# g    225
# b    126
# Name: label, dtype: int64

# %%
from sklearn import preprocessing as pre
new = pre.LabelEncoder()
data['label'] = new.fit_transform(data['label'])

# %%
data.label.value_counts()
# Out:
# 1    225
# 0    126
# Name: label, dtype: int64

# %%
data.describe()
# Out:
#          feature1  feature2    feature3    feature4    feature5    feature6  \
# count  351.000000     351.0  351.000000  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342    0.044372    0.601068    0.115889
# std      0.311155       0.0    0.497708    0.441435    0.519862    0.460810
# min      0.000000       0.0   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135   -0.064735    0.412660   -0.024795
# 50%      1.000000       0.0    0.871110    0.016310    0.809200    0.022800
# 75%      1.000000       0.0    1.000000    0.194185    1.000000    0.334655
# max      1.000000       0.0    1.000000    1.000000    1.000000    1.000000
#
#          feature7    feature8    feature9   feature10  ...   feature26  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.550095    0.119360    0.511848    0.181345  ...   -0.071187
# ...

# %%
data.rename(columns = {'feature1':'pulse1'}, inplace =True)

# %%
data.describe()
# Out:
#            pulse1  feature2    feature3    feature4    feature5    feature6  \
# count  351.000000     351.0  351.000000  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342    0.044372    0.601068    0.115889
# std      0.311155       0.0    0.497708    0.441435    0.519862    0.460810
# min      0.000000       0.0   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135   -0.064735    0.412660   -0.024795
# 50%      1.000000       0.0    0.871110    0.016310    0.809200    0.022800
# 75%      1.000000       0.0    1.000000    0.194185    1.000000    0.334655
# max      1.000000       0.0    1.000000    1.000000    1.000000    1.000000
#
#          feature7    feature8    feature9   feature10  ...   feature26  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.550095    0.119360    0.511848    0.181345  ...   -0.071187
# ...

# %%
column_names = list(data.columns)

# %% [markdown]
# EDA AND DATA PREPROCESSING

# %%
column_names = column_names[1:32]

# %%
for i in range(1,17):
    data['pulse'+str(i+1)] = np.nan

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 51 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pulse1     351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
data['pulse2'] = np.sqrt((data.feature3)**2+ data.feature4**2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 51 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pulse1     351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
data['pulse3'] = np.sqrt((data.feature5)**2+ data.feature6**2)
data['pulse4'] = np.sqrt((data.feature7)**2+ data.feature8**2)
data['pulse5'] = np.sqrt((data.feature9)**2+ data.feature10**2)
data['pulse6'] = np.sqrt((data.feature11)**2+ data.feature12**2)
data['pulse7'] = np.sqrt((data.feature13)**2+ data.feature14**2)
data['pulse8'] = np.sqrt((data.feature15)**2+ data.feature16**2)
data['pulse9'] = np.sqrt((data.feature17)**2+ data.feature18**2)
data['pulse10'] = np.sqrt((data.feature19)**2+ data.feature20**2)
data['pulse11'] = np.sqrt((data.feature21)**2+ data.feature22**2)
data['pulse12'] = np.sqrt((data.feature23)**2+ data.feature24**2)
data['pulse13'] = np.sqrt((data.feature25)**2+ data.feature26**2)
data['pulse14'] = np.sqrt((data.feature27)**2+ data.feature28**2)
data['pulse15'] = np.sqrt((data.feature29)**2+ data.feature30**2)
data['pulse16'] = np.sqrt((data.feature31)**2+ data.feature32**2)
data['pulse17'] = np.sqrt((data.feature33)**2+ data.feature34**2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 51 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pulse1     351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
for i in range(3,35):
    data.pop('feature'+str(i))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pulse1    351 non-null    int64
#  1   feature2  351 non-null    int64
#  2   label     351 non-null    int32
#  3   pulse2    351 non-null    float64
#  4   pulse3    351 non-null    float64
#  5   pulse4    351 non-null    float64
#  6   pulse5    351 non-null    float64
#  7   pulse6    351 non-null    float64
#  8   pulse7    351 non-null    float64
#  9   pulse8    351 non-null    float64
#  10  pulse9    351 non-null    float64
#  11  pulse10   351 non-null    float64
#  12  pulse11   351 non-null    float64
#  13  pulse12   351 non-null    float64
#  14  pulse13   351 non-null    float64
#  15  pulse14   351 non-null    float64
#  16  pulse15   351 non-null    float64
#  17  pulse16   351 non-null    float64
#  18  pulse17   351 non-null    float64
# ...

# %%
data.head()
# Out:
#    pulse1  feature2  label    pulse2    pulse3    pulse4    pulse5    pulse6  \
# 0       1         0      1  0.997131  0.852742  0.915266  1.000707  0.870724
# 1       1         0      0  1.017572  0.998137  0.942259  1.001034  0.847188
# 2       1         0      1  1.000566  1.000012  1.007248  0.889731  0.732773
# 3       1         0      0  1.097247  1.414214  1.227669  0.000000  0.000000
# 4       1         0      1  1.000288  0.943663  0.949964  0.788756  0.565571
#
#      pulse7    pulse8    pulse9   pulse10   pulse11   pulse12   pulse13  \
# 0  0.747711  0.715933  0.927438  0.665204  0.642358  0.600641  0.764589
# 1  0.777472  1.103654  0.624795  1.053385  0.471703  0.400367  0.334560
# 2  0.854470  0.545918  0.848788  0.760162  0.760350  0.450305  0.701934
# 3  0.000000  1.010481  0.668806  1.138712  1.220512  0.000000  1.350022
# 4  0.564135  0.440103  0.572452  0.484968  0.360744  0.529294  0.652408
#
#     pulse14   pulse15   pulse16   pulse17
# ...

# %%
corr_matrix = data.corr()
corr_matrix["label"].sort_values(ascending=False)
# Out:
# label       1.000000
# pulse1      0.465614
# pulse8      0.208694
# pulse17     0.174931
# pulse5      0.162006
# pulse4      0.155708
# pulse3      0.146386
# pulse11     0.119333
# pulse7      0.116290
# pulse6      0.097697
# pulse2      0.094738
# pulse9      0.070377
# pulse10     0.012782
# pulse13    -0.005044
# pulse15    -0.005682
# pulse12    -0.007293
# pulse16    -0.022617
# pulse14    -0.374283
# feature2         NaN
# Name: label, dtype: float64

# %%
pd.plotting.scatter_matrix(data)
# Out:
# D:\New folder\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# D:\New folder\lib\site-packages\pandas\plotting\_matplotlib\misc.py:81: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# D:\New folder\lib\site-packages\pandas\plotting\_matplotlib\misc.py:71: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# array([[<AxesSubplot:xlabel='pulse1', ylabel='pulse1'>,
#         <AxesSubplot:xlabel='feature2', ylabel='pulse1'>,
#         <AxesSubplot:xlabel='label', ylabel='pulse1'>,
#         <AxesSubplot:xlabel='pulse2', ylabel='pulse1'>,
#         <AxesSubplot:xlabel='pulse3', ylabel='pulse1'>,
# ...

# %%
X = data.drop(['label'],axis=1)
y = data['label'].copy

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pulse1    351 non-null    int64
#  1   feature2  351 non-null    int64
#  2   pulse2    351 non-null    float64
#  3   pulse3    351 non-null    float64
#  4   pulse4    351 non-null    float64
#  5   pulse5    351 non-null    float64
#  6   pulse6    351 non-null    float64
#  7   pulse7    351 non-null    float64
#  8   pulse8    351 non-null    float64
#  9   pulse9    351 non-null    float64
#  10  pulse10   351 non-null    float64
#  11  pulse11   351 non-null    float64
#  12  pulse12   351 non-null    float64
#  13  pulse13   351 non-null    float64
#  14  pulse14   351 non-null    float64
#  15  pulse15   351 non-null    float64
#  16  pulse16   351 non-null    float64
#  17  pulse17   351 non-null    float64
# dtypes: float64(16), int64(2)
# memory usage: 49.5 KB

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pulse1    351 non-null    int64
#  1   feature2  351 non-null    int64
#  2   pulse2    351 non-null    float64
#  3   pulse3    351 non-null    float64
#  4   pulse4    351 non-null    float64
#  5   pulse5    351 non-null    float64
#  6   pulse6    351 non-null    float64
#  7   pulse7    351 non-null    float64
#  8   pulse8    351 non-null    float64
#  9   pulse9    351 non-null    float64
#  10  pulse10   351 non-null    float64
#  11  pulse11   351 non-null    float64
#  12  pulse12   351 non-null    float64
#  13  pulse13   351 non-null    float64
#  14  pulse14   351 non-null    float64
#  15  pulse15   351 non-null    float64
#  16  pulse16   351 non-null    float64
#  17  pulse17   351 non-null    float64
# dtypes: float64(16), int64(2)
# memory usage: 49.5 KB

# %%
data = data.astype({"pulse1":'float'})

# %%
X = X.astype({"pulse1":'float'})

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pulse1    351 non-null    float64
#  1   feature2  351 non-null    int64
#  2   pulse2    351 non-null    float64
#  3   pulse3    351 non-null    float64
#  4   pulse4    351 non-null    float64
#  5   pulse5    351 non-null    float64
#  6   pulse6    351 non-null    float64
#  7   pulse7    351 non-null    float64
#  8   pulse8    351 non-null    float64
#  9   pulse9    351 non-null    float64
#  10  pulse10   351 non-null    float64
#  11  pulse11   351 non-null    float64
#  12  pulse12   351 non-null    float64
#  13  pulse13   351 non-null    float64
#  14  pulse14   351 non-null    float64
#  15  pulse15   351 non-null    float64
#  16  pulse16   351 non-null    float64
#  17  pulse17   351 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# TEST AND TRAINING DATA DEFINITION

# %%
training_data = data.sample(frac=0.8, random_state=25)
testing_data = data.drop(training_data.index)

# %%
X_train= training_data.drop(['label'], axis =1)
X_test= testing_data.drop(['label'], axis= 1)
y_train= training_data['label'].copy()
y_test= testing_data['label'].copy()

# %% [markdown]
# DECISION TREE- Model 1

# %%
from sklearn.tree import DecisionTreeClassifier #Desision 
clf = DecisionTreeClassifier(random_state=2)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=2)

# %%
y_test_pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_a = confusion_matrix(y_test, y_test_pred, labels=[0,1])
print(confusion_matrix_a)
# Out:
# [[12  7]
#  [ 6 45]]

# %%
import sklearn
from sklearn.metrics import accuracy_score
sklearn.metrics.accuracy_score(y_test, y_test_pred)*100
# Out:
# 81.42857142857143

# %%
specificity_a= confusion_matrix_a[0,0]/(confusion_matrix_a[0,0]+confusion_matrix_a[0,1])
print(specificity_a)
# Out:
# 0.631578947368421

# %%
sensitivity_a = confusion_matrix_a[1,1]/(confusion_matrix_a[1,0]+confusion_matrix_a[1,1])
print(sensitivity_a)
# Out:
# 0.8823529411764706

# %% [markdown]
# LOGISTIC REGRESSION - Model 2

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(class_weight='balanced')
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79        19
#            1       0.89      0.98      0.93        51
#
#     accuracy                           0.90        70
#    macro avg       0.91      0.83      0.86        70
# weighted avg       0.90      0.90      0.89        70

# %%
sklearn.metrics.accuracy_score(y_test, predictions)*100
# Out:
# 90.0

# %% [markdown]
# k Nearest Neighbour Algorithm -KNN - Model 3

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=7)
  
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
predicted= knn.predict(X_test)

# %%
sklearn.metrics.accuracy_score(y_test,predicted)*100
# Out:
# 87.14285714285714

# %% [markdown]
# Random Forest - Model-4

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators = 150) 
 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

from sklearn import metrics 
print()

print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.8714285714285714
